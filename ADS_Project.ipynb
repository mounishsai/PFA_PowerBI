# %%
import pandas as pd
import numpy as np
# read datasdet using pandas
df = pd.read_excel('Finance Database1.xlsx')
df.head()
# Out:
#       Type       Component  Jan-18  Feb-18  Mar-18  Apr-18  May-18  Jun-18  \
# 0   Income          Salary   30000   30000   30000   30000   30000   30000
# 1   Income        Source 2    1000    1000    1000    1000    1000    1000
# 2  Savings    Mutual funds    5000    5000    5000    5000    5000    5000
# 3  Savings  Emergency Fund    2000    2000    2000    2000    2000    2000
# 4  Savings   Fixed Deposit    2000    2000    2000    2000    2000    2000
#
#    Jul-18  Aug-18  ...  Apr-20  May-20  Jun-20  Jul-20  Aug-20  Sep-20  \
# 0   30000   30000  ...   43000   43000   43000   43000   43000   43000
# 1    1000    1000  ...    4000    4000    4000    6000    6000    6000
# 2    5000    5000  ...    7000    7000    7000    7000    7000    7000
# 3    2000       0  ...       0    2000       0    1000    1000    1000
# 4    2000    2000  ...       0       0    2000       0       0    2000
#
#    Oct-20  Nov-20  Dec-20  Jan-21
# 0   43000   51500   51500   51500
# ...

# %%
df.shape
# Out:
# (12, 39)

# %%
df.describe()
# Out:
#              Jan-18        Feb-18        Mar-18        Apr-18        May-18  \
# count     12.000000     12.000000     12.000000     12.000000     12.000000
# mean    7333.333333   7333.333333   7333.333333   7333.333333   7333.333333
# std     9582.971008   9700.827831   9582.971008   9700.827831   9582.971008
# min      500.000000      0.000000    500.000000      0.000000    500.000000
# 25%     1000.000000   1375.000000   1000.000000   1375.000000   1000.000000
# 50%     2250.000000   2250.000000   2250.000000   2250.000000   2250.000000
# 75%    10000.000000   9250.000000  10000.000000   9250.000000  10000.000000
# max    31000.000000  31000.000000  31000.000000  31000.000000  31000.000000
#
#              Jun-18        Jul-18        Aug-18        Sep-18        Oct-18  \
# count     12.000000     12.000000     12.000000     12.000000     12.000000
# mean    7333.333333   7333.333333   7333.333333   8583.333333   8583.333333
# ...

# %%
combined_row = df.iloc[0] + df.iloc[1]
combined_row2 = df.iloc[2] + df.iloc[3]+df.iloc[4] + df.iloc[5]
combined_row3 = df.iloc[6] + df.iloc[7]+df.iloc[8] + df.iloc[9]+df.iloc[10] + df.iloc[11]

# Drop the second row
df.drop([9,10,11])

# Assign the combined row as the first row
df.iloc[0] = combined_row
df.iloc[1] = combined_row2
df.iloc[2] = combined_row3

print(df)
# Out:
#                                           Type  \
# 0                                 IncomeIncome
# 1                 SavingsSavingsSavingsSavings
# 2   ExpenseExpenseExpenseExpenseExpenseExpense
# 3                                      Savings
# 4                                      Savings
# 5                                      Savings
# 6                                      Expense
# 7                                      Expense
# 8                                      Expense
# 9                                      Expense
# 10                                     Expense
# 11                                     Expense
#
#                                             Component  Jan-18  Feb-18  Mar-18  \
# 0                                      SalarySource 2   31000   31000   31000
# 1   Mutual fundsEmergency FundFixed DepositLiquid ...   10000    9000   10000
# 2   House RentGroceries & FoodHealthEMIsLeisureSho...   21000   22000   21000
# ...

# %%
df.drop([3,4,5,6,7,8,9,10,11])
# Out:
#                                          Type  \
# 0                                IncomeIncome
# 1                SavingsSavingsSavingsSavings
# 2  ExpenseExpenseExpenseExpenseExpenseExpense
#
#                                            Component  Jan-18  Feb-18  Mar-18  \
# 0                                     SalarySource 2   31000   31000   31000
# 1  Mutual fundsEmergency FundFixed DepositLiquid ...   10000    9000   10000
# 2  House RentGroceries & FoodHealthEMIsLeisureSho...   21000   22000   21000
#
#    Apr-18  May-18  Jun-18  Jul-18  Aug-18  ...  Apr-20  May-20  Jun-20  \
# 0   31000   31000   31000   31000   31000  ...   47000   47000   47000
# 1    9000   10000    9000    8000    7000  ...    7500    7500   10500
# 2   22000   21000   22000   23000   24000  ...   39500   39500   36500
#
#    Jul-20  Aug-20  Sep-20  Oct-20  Nov-20  Dec-20  Jan-21
# 0   49000   49000   49000   49000   57500   57500   57500
# 1    6500    6000    7500    9500   14000   12000   13000
# ...

# %%
import pandas as pd
import numpy as np
# read datasdet using pandas
df2 = pd.read_excel('finance_final1.xlsx')
df2.head()
# Out:
#    Total_income  total_ expense
# 0         31000           21000
# 1         31000           22000
# 2         31000           21000
# 3         31000           22000
# 4         31000           21000

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Assuming you have loaded your dataset into a DataFrame called df
# Let's say the columns are 'Total Income' and 'Total Expenses'

# Extracting the independent variable (X) and dependent variable (y)
X = df2[['Total_income']]  # Features
y = df2['total_ expense'] # Target variable

# Creating a linear regression model
model = LinearRegression()

# Fitting the model
model.fit(X, y)

# Printing the coefficients
print("Intercept:", model.intercept_)
print("Coefficient:", model.coef_[0])
# Out:
# Intercept: -6998.44061764123
# Coefficient: 0.955848957116236
